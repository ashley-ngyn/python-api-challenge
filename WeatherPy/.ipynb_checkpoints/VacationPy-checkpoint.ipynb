# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e2f73774-4a21-4235-8314-027e79488e0f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  blackmans bay -43.0167  147.3167     17.07        68         100
# 1        1     banda aceh   5.5577   95.3222     28.52        75          58
# 2        2        manggar  -2.8833  108.2667     26.38        85         100
# 3        3      adamstown -25.0660 -130.1015     23.44        91         100
# 4        4        kavieng  -2.5744  150.7967     28.43        79          99
#
#    Wind Speed Country        Date
# 0        2.09      AU  1706697972
# 1        5.34      ID  1706697972
# 2        1.51      ID  1706697973
# 3       12.13      PN  1706697754
# 4        3.13      PG  1706697973

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#source 05 helped with hvplotting
map_plot = city_data_df.hvplot.points(x="Lng", 
                                      y="Lat", 
                                      geo=True, 
                                      tiles='OSM', 
                                      size='Humidity', 
                                      color='City',
                                      scale=1,
                                      alpha=0.5,
                                      frame_width=700,
                                      frame_height=500,
                                      xlabel='Longitude', 
                                      ylabel='Latitude')

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

#make a copy of the dataframe
ideal_weather_df = city_data_df.copy()

#ideal weather conditions: temperature lower than 27C but higher than 21C, wind speeds less than 4.5m/s, zero cloudiness

ideal_weather_df = ideal_weather_df.loc[(ideal_weather_df['Max Temp'] < 27) &
                                        (ideal_weather_df['Max Temp'] > 21) &
                                        (ideal_weather_df['Wind Speed'] < 4.5) &
                                        (ideal_weather_df['Cloudiness'] == 0)]

# Drop any rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 167      167  katsuren-haebaru  26.3369  127.8719     23.43        80
# 240      240         thurgoona -36.0451  146.9919     25.36        98
# 373      373         tazacorte  28.6290  -17.9293     22.86        28
# 397      397        vila velha -20.3297  -40.2925     23.30        94
# 523      523        champerico  14.3000  -91.9167     24.50        77
# 546      546   santa terezinha -29.9002  -50.0904     21.95        75
#
#      Cloudiness  Wind Speed Country        Date
# 167           0        3.60      JP  1706698015
# 240           0        2.24      AU  1706698032
# 373           0        3.60      ES  1706698062
# 397           0        3.09      BR  1706698067
# 523           0        1.72      GT  1706698097
# 546           0        3.15      BR  1706698103

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
#source 06 to copy specific columns from one dataframe to another
hotel_df = ideal_weather_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 167  katsuren-haebaru      JP  26.3369  127.8719        80
# 240         thurgoona      AU -36.0451  146.9919        98
# 373         tazacorte      ES  28.6290  -17.9293        28
# 397        vila velha      BR -20.3297  -40.2925        94
# 523        champerico      GT  14.3000  -91.9167        77
# 546   santa terezinha      BR -29.9002  -50.0904        75

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
#source 07 for specific categories in geoapify
categories = 'accommodation.hotel'

# Set parameters to search for a hotel
radius = 10000
params = {'categories':categories,
          'apiKey':geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")


# Iterate through the hotel_df DataFrame

#source 08 to search through dataframe
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{lng},{lat},{radius}'
    params["bias"] = f'proximity:{lng},{lat}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# katsuren-haebaru - nearest hotel: No hotel found
# thurgoona - nearest hotel: Astor Hotel Motel
# tazacorte - nearest hotel: App Leyma
# vila velha - nearest hotel: Hotel Prainha
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# santa terezinha - nearest hotel: Pousada Santa Terezinha
#                  City Country      Lat       Lng  Humidity  \
# 167  katsuren-haebaru      JP  26.3369  127.8719        80
# 240         thurgoona      AU -36.0451  146.9919        98
# 373         tazacorte      ES  28.6290  -17.9293        28
# 397        vila velha      BR -20.3297  -40.2925        94
# 523        champerico      GT  14.3000  -91.9167        77
# 546   santa terezinha      BR -29.9002  -50.0904        75
#
#                            Hotel Name
# 167                    No hotel found
# 240                 Astor Hotel Motel
# 373                         App Leyma
# 397                     Hotel Prainha
# 523  Hotel y Restaurante El Submarino
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
#source 05 helped with hvplot formatting
#source 10 helped with adding a hover message and a learning assistant helped
hotel_map_plot = hotel_df.hvplot.points("Lng", 
                                        "Lat", 
                                        geo = True, 
                                        size = "Humidity",
                                        scale=1,
                                        color = "City",
                                        alpha=0.5,
                                        tiles = "OSM",
                                        hover_cols = ["Hotel Name", "Country"],
                                        frame_width=700,
                                        frame_height=500)

# Display the map
hotel_map_plot

#note: see below for the hover requirement
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)

# %%
#with the help of learningassistant and source 11

#the hover message doesnt work in jupyter notebook, so it has to be opened up in another browser the code below
hvplot.show(hotel_map_plot)

#saved plot to show all the features
#there is also an example photo named fig_vacation.png in the output_data folder
hvplot.save(hotel_map_plot, 'fig_vacation.html')
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p3243', ...)
# Launching server at http://localhost:50806
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p3330', ...)
